# %% [markdown]
# # Group Work

# %%
import mysql.connector 
import config
import requests

# %%
## Connect to DB server on AWS
cnx = mysql.connector .connect(
    host = config.host,
    user = config.user,
    passwd = config.password
)

cursor = cnx.cursor()

# %%
## Create new DB 
from mysql.connector import errorcode
db_name = 'crossfit_gym_reviews'

# %%
# Will connect to yelp API and fetch a list of businesses
term = 'Crossfit Gyms'
location = 'Manhattan, New York, NY'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(config.yelp_api_key), #here is my api key
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# ...

# %%
# converts 'response' ^^^ to json
import json
json.loads(response.content)
# Out:
# {'businesses': [{'id': '0zil0OKvw41ZUWJsiHwdQw',
#    'alias': 'crossfit-nyc-the-black-box-new-york-2',
#    'name': 'CrossFit NYC: The Black Box',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8C64tE0MWYpBtIsTRghQWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crossfit-nyc-the-black-box-new-york-2?adjust_creative=8zdw6KxxLi5qVKkDCr9PEg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8zdw6KxxLi5qVKkDCr9PEg',
#    'review_count': 82,
#    'categories': [{'alias': 'intervaltraininggyms',
#      'title': 'Interval Training Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7456231, 'longitude': -73.9898357},
#    'transactions': [],
#    'location': {'address1': '50 W 28th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 W 28th St', 'Fl 2', 'New York, NY 10001']},
# ...

# %% [markdown]
# In order to get the review from yelp go here:
# https://www.yelp.com/developers/documentation/v3/business_reviews
#
# We need to feed the ID of the business (where **{id}** is located in the url sample below)
# From this: https://api.yelp.com/v3/businesses/{id}/reviews
# To this: https://api.yelp.com/v3/businesses/0zil0OKvw41ZUWJsiHwdQw/reviews

# %%
# term = 'Crossfit Gyms'
# location = 'Manhattan, New York, NY'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/CQ5KaqjOQGkX5D-96m3PyQ/reviews'

headers = {
        'Authorization': 'Bearer {}'.format(config.yelp_api_key), #here is my api key
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response_yelp_review = requests.get(url, headers=headers, params=url_params)
print(response_yelp_review)
print(type(response_yelp_review.text))
print(response_yelp_review.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# ...

# %%
# converts 'response_yelp_review' ^^^ to json
import json
json.loads(response_yelp_review.content)
# Out:
# {'reviews': [{'id': 'X1YM6Z5DSKbUZOCC7q-FsQ',
#    'url': 'https://www.yelp.com/biz/crossfit-spot-new-york?adjust_creative=8zdw6KxxLi5qVKkDCr9PEg&hrid=X1YM6Z5DSKbUZOCC7q-FsQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=8zdw6KxxLi5qVKkDCr9PEg',
#    'text': "Although this was my first Crossfit gym, I'm reviewing SPOT after I've been a member at several different CrossFit gyms in the New York area. \n\nHere are...",
#    'rating': 5,
#    'time_created': '2019-07-10 11:45:01',
#    'user': {'id': '0IutQZx64bEJ1yXnofbU2w',
#     'profile_url': 'https://www.yelp.com/user_details?userid=0IutQZx64bEJ1yXnofbU2w',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/-nBrw4KvoJ7ARNUsDk53Bw/o.jpg',
#     'name': 'Kovi K.'}},
#   {'id': 'TudRZn33MANtQQpxPzTGIg',
# ...

# %% [markdown]
# In order to get the review from yelp go here:
# https://www.yelp.com/developers/documentation/v3/business_reviews
#
# We need to feed the ID of the business (where **{id}** is located in the url sample below)
# From this: https://api.yelp.com/v3/businesses/{id}
# To this: https://api.yelp.com/v3/businesses/0zil0OKvw41ZUWJsiHwdQw

# %%
# term = 'Crossfit Gyms'
# location = 'Manhattan, New York, NY'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/CQ5KaqjOQGkX5D-96m3PyQ'

headers = {
        'Authorization': 'Bearer {}'.format(config.yelp_api_key), #here is my api key
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response_biz_detail = requests.get(url, headers=headers, params=url_params)
print(response_biz_detail)
print(type(response_biz_detail.text))
print(response_biz_detail.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# ...

# %%
import json
json.loads(response_biz_detail.content)
# Out:
# {'id': 'CQ5KaqjOQGkX5D-96m3PyQ',
#  'alias': 'crossfit-spot-new-york',
#  'name': 'CrossFit SPOT',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vn-8TuLQMHeGRpJ-mR8oSw/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/crossfit-spot-new-york?adjust_creative=8zdw6KxxLi5qVKkDCr9PEg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=8zdw6KxxLi5qVKkDCr9PEg',
#  'phone': '+12127130348',
#  'display_phone': '(212) 713-0348',
#  'review_count': 44,
#  'categories': [{'alias': 'intervaltraininggyms',
#    'title': 'Interval Training Gyms'}],
#  'rating': 4.5,
#  'location': {'address1': '55 Amsterdam Ave',
#   'address2': None,
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10023',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['55 Amsterdam Ave', 'New York, NY 10023'],
#   'cross_streets': '62nd St & 64th St'},
#  'coordinates': {'latitude': 40.77209, 'longitude': -73.98616},
# ...
